# %%
import requests
import pandas as pd

# %%
API_KEY = "d6b14f6fc1d9ff43d4fcd75eddbde602"

CITY = "Khammam"

url = f"https://api.openweathermap.org/data/2.5/weather?q={CITY}&appid={API_KEY}&units=metric"

response = requests.get(url)

weather_data = response.json()

weather_data
# Out:
# {'coord': {'lon': 80.15, 'lat': 17.25},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 33.1,
#   'feels_like': 36.49,
#   'temp_min': 33.1,
#   'temp_max': 33.1,
#   'pressure': 1006,
#   'humidity': 50,
#   'sea_level': 1006,
#   'grnd_level': 991},
#  'visibility': 10000,
#  'wind': {'speed': 4.61, 'deg': 146, 'gust': 4.88},
#  'clouds': {'all': 100},
#  'dt': 1778906120,
#  'sys': {'country': 'IN', 'sunrise': 1778890054, 'sunset': 1778936649},
#  'timezone': 19800,
#  'id': 1267076,
#  'name': 'Khammam',
#  'cod': 200}

# %%
import requests

CITY = "Khammam"

url = f"https://wttr.in/{CITY}?format=j1"

response = requests.get(url)

weather_data = response.json()

weather_data
# Out:
# {'current_condition': [{'FeelsLikeC': '36',
#    'FeelsLikeF': '97',
#    'cloudcover': '12',
#    'humidity': '52',
#    'observation_time': '04:29 AM',
#    'precipInches': '0.0',
#    'precipMM': '0.0',
#    'pressure': '1006',
#    'pressureInches': '30',
#    'temp_C': '32',
#    'temp_F': '90',
#    'uvIndex': '4',
#    'visibility': '10',
#    'visibilityMiles': '6',
#    'weatherCode': '113',
#    'weatherDesc': [{'value': 'Sunny'}],
#    'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#    'winddir16Point': 'SSE',
#    'winddirDegree': '148',
#    'windspeedKmph': '15',
#    'windspeedMiles': '9'}],
#  'nearest_area': [{'areaName': [{'value': 'Khammam'}],
#    'country': [{'value': 'India'}],
#    'latitude': '17.250',
#    'longitude': '80.150',
#    'population': '170503',
#    'region': [{'value': 'Telangana'}],
#    'weatherUrl': [{'value': 'https://www.worldweatheronline.com/v2/weather.aspx?q=17.25,80.15'}]}],
#  'request': [{'query': 'Lat 17.25 and Lon 80.15', 'type': 'LatLon'}],
#  'weather': [{'astronomy': [{'moon_illumination': '1',
#      'moon_phase': 'New Moon',
#      'moonrise': '04:45 AM',
#      'moonset': '06:12 PM',
#      'sunrise': '05:38 AM',
#      'sunset': '06:34 PM'}],
#    'avgtempC': '33',
#    'avgtempF': '91',
#    'date': '2026-05-16',
#    'hourly': [{'DewPointC': '23',
#      'DewPointF': '73',
#      'FeelsLikeC': '35',
#      'FeelsLikeF': '96',
#      'HeatIndexC': '35',
#      'HeatIndexF': '96',
#      'WindChillC': '31',
#      'WindChillF': '88',
#      'WindGustKmph': '25',
#      'WindGustMiles': '16',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '98',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '91',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '94',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '6',
#      'diffRad': '0.0',
#      'humidity': '63',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1003',
#      'pressureInches': '30',
#      'shortRad': '0.0',
#      'tempC': '31',
#      'tempF': '88',
#      'time': '0',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Clear '}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#      'winddir16Point': 'SE',
#      'winddirDegree': '143',
#      'windspeedKmph': '20',
#      'windspeedMiles': '13'},
#     {'DewPointC': '23',
#      'DewPointF': '73',
#      'FeelsLikeC': '34',
#      'FeelsLikeF': '93',
#      'HeatIndexC': '34',
#      'HeatIndexF': '93',
#      'WindChillC': '30',
#      'WindChillF': '86',
#      'WindGustKmph': '23',
#      'WindGustMiles': '14',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '99',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '87',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '87',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '8',
#      'diffRad': '0.0',
#      'humidity': '65',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1003',
#      'pressureInches': '30',
#      'shortRad': '0.0',
#      'tempC': '30',
#      'tempF': '86',
#      'time': '300',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Clear '}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#      'winddir16Point': 'SSE',
#      'winddirDegree': '152',
#      'windspeedKmph': '18',
#      'windspeedMiles': '11'},
#     {'DewPointC': '23',
#      'DewPointF': '73',
#      'FeelsLikeC': '33',
#      'FeelsLikeF': '92',
#      'HeatIndexC': '33',
#      'HeatIndexF': '92',
#      'WindChillC': '30',
#      'WindChillF': '85',
#      'WindGustKmph': '21',
#      'WindGustMiles': '13',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '98',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '89',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '87',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '8',
#      'diffRad': '4.8',
#      'humidity': '67',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1004',
#      'pressureInches': '30',
#      'shortRad': '8.0',
#      'tempC': '30',
#      'tempF': '85',
#      'time': '600',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'SE',
#      'winddirDegree': '139',
#      'windspeedKmph': '17',
#      'windspeedMiles': '10'},
#     {'DewPointC': '21',
#      'DewPointF': '71',
#      'FeelsLikeC': '36',
#      'FeelsLikeF': '97',
#      'HeatIndexC': '36',
#      'HeatIndexF': '97',
#      'WindChillC': '32',
#      'WindChillF': '90',
#      'WindGustKmph': '17',
#      'WindGustMiles': '11',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '98',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '94',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '88',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '12',
#      'diffRad': '82.0',
#      'humidity': '52',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1006',
#      'pressureInches': '30',
#      'shortRad': '151.2',
#      'tempC': '32',
#      'tempF': '90',
#      'time': '900',
#      'uvIndex': '4',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'SSE',
#      'winddirDegree': '148',
#      'windspeedKmph': '15',
#      'windspeedMiles': '9'},
#     {'DewPointC': '21',
#      'DewPointF': '71',
#      'FeelsLikeC': '37',
#      'FeelsLikeF': '99',
#      'HeatIndexC': '37',
#      'HeatIndexF': '99',
#      'WindChillC': '33',
#      'WindChillF': '92',
#      'WindGustKmph': '16',
#      'WindGustMiles': '10',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '97',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '80',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '93',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '13',
#      'diffRad': '62.4',
#      'humidity': '50',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1004',
#      'pressureInches': '30',
#      'shortRad': '88.8',
#      'tempC': '33',
#      'tempF': '92',
#      'time': '1200',
#      'uvIndex': '5',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'SSE',
#      'winddirDegree': '156',
#      'windspeedKmph': '14',
#      'windspeedMiles': '9'},
#     {'DewPointC': '20',
#      'DewPointF': '67',
#      'FeelsLikeC': '42',
#      'FeelsLikeF': '108',
#      'HeatIndexC': '42',
#      'HeatIndexF': '108',
#      'WindChillC': '38',
#      'WindChillF': '101',
#      'WindGustKmph': '10',
#      'WindGustMiles': '6',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '97',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '84',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '92',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '12',
#      'diffRad': '84.9',
#      'humidity': '33',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1001',
#      'pressureInches': '30',
#      'shortRad': '645.1',
#      'tempC': '38',
#      'tempF': '101',
#      'time': '1500',
#      'uvIndex': '4',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'SSW',
#      'winddirDegree': '204',
#      'windspeedKmph': '9',
#      'windspeedMiles': '5'},
#     {'DewPointC': '20',
#      'DewPointF': '67',
#      'FeelsLikeC': '39',
#      'FeelsLikeF': '103',
#      'HeatIndexC': '39',
#      'HeatIndexF': '103',
#      'WindChillC': '36',
#      'WindChillF': '97',
#      'WindGustKmph': '18',
#      'WindGustMiles': '11',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '96',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '93',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '88',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '9',
#      'diffRad': '24.1',
#      'humidity': '38',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1002',
#      'pressureInches': '30',
#      'shortRad': '73.7',
#      'tempC': '36',
#      'tempF': '97',
#      'time': '1800',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'SE',
#      'winddirDegree': '131',
#      'windspeedKmph': '13',
#      'windspeedMiles': '8'},
#     {'DewPointC': '22',
#      'DewPointF': '71',
#      'FeelsLikeC': '34',
#      'FeelsLikeF': '94',
#      'HeatIndexC': '34',
#      'HeatIndexF': '94',
#      'WindChillC': '31',
#      'WindChillF': '87',
#      'WindGustKmph': '34',
#      'WindGustMiles': '21',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '96',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '90',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '85',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '6',
#      'diffRad': '6.0',
#      'humidity': '58',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1004',
#      'pressureInches': '30',
#      'shortRad': '18.4',
#      'tempC': '31',
#      'tempF': '87',
#      'time': '2100',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Clear '}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#      'winddir16Point': 'SE',
#      'winddirDegree': '131',
#      'windspeedKmph': '24',
#      'windspeedMiles': '15'}],
#    'maxtempC': '39',
#    'maxtempF': '102',
#    'mintempC': '30',
#    'mintempF': '85',
#    'sunHour': '13.0',
#    'totalSnow_cm': '0.0',
#    'uvIndex': '6'},
#   {'astronomy': [{'moon_illumination': '0',
#      'moon_phase': 'Waxing Crescent',
#      'moonrise': '05:39 AM',
#      'moonset': '07:21 PM',
#      'sunrise': '05:37 AM',
#      'sunset': '06:34 PM'}],
#    'avgtempC': '34',
#    'avgtempF': '93',
#    'date': '2026-05-17',
#    'hourly': [{'DewPointC': '22',
#      'DewPointF': '72',
#      'FeelsLikeC': '33',
#      'FeelsLikeF': '92',
#      'HeatIndexC': '33',
#      'HeatIndexF': '92',
#      'WindChillC': '30',
#      'WindChillF': '85',
#      'WindGustKmph': '21',
#      'WindGustMiles': '13',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '95',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '86',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '89',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '17',
#      'diffRad': '0.0',
#      'humidity': '65',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1004',
#      'pressureInches': '30',
#      'shortRad': '0.0',
#      'tempC': '30',
#      'tempF': '85',
#      'time': '0',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Clear '}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#      'winddir16Point': 'S',
#      'winddirDegree': '171',
#      'windspeedKmph': '16',
#      'windspeedMiles': '10'},
#     {'DewPointC': '24',
#      'DewPointF': '75',
#      'FeelsLikeC': '32',
#      'FeelsLikeF': '90',
#      'HeatIndexC': '32',
#      'HeatIndexF': '90',
#      'WindChillC': '28',
#      'WindChillF': '83',
#      'WindGustKmph': '17',
#      'WindGustMiles': '11',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '93',
#      'chanceofovercast': '47',
#      'chanceofrain': '0',
#      'chanceofremdry': '80',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '70',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '31',
#      'diffRad': '0.0',
#      'humidity': '78',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1004',
#      'pressureInches': '30',
#      'shortRad': '0.0',
#      'tempC': '28',
#      'tempF': '83',
#      'time': '300',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '116',
#      'weatherDesc': [{'value': 'Partly Cloudy '}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#      'winddir16Point': 'S',
#      'winddirDegree': '179',
#      'windspeedKmph': '13',
#      'windspeedMiles': '8'},
#     {'DewPointC': '24',
#      'DewPointF': '76',
#      'FeelsLikeC': '33',
#      'FeelsLikeF': '91',
#      'HeatIndexC': '33',
#      'HeatIndexF': '91',
#      'WindChillC': '28',
#      'WindChillF': '83',
#      'WindGustKmph': '14',
#      'WindGustMiles': '9',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '92',
#      'chanceofovercast': '88',
#      'chanceofrain': '0',
#      'chanceofremdry': '88',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '16',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '38',
#      'diffRad': '17.7',
#      'humidity': '79',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1005',
#      'pressureInches': '30',
#      'shortRad': '36.5',
#      'tempC': '28',
#      'tempF': '83',
#      'time': '600',
#      'uvIndex': '0',
#      'visibility': '9',
#      'visibilityMiles': '5',
#      'weatherCode': '200',
#      'weatherDesc': [{'value': 'Thundery outbreaks in nearby'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0016_thundery_showers.png'}],
#      'winddir16Point': 'SSE',
#      'winddirDegree': '164',
#      'windspeedKmph': '11',
#      'windspeedMiles': '7'},
#     {'DewPointC': '22',
#      'DewPointF': '71',
#      'FeelsLikeC': '37',
#      'FeelsLikeF': '99',
#      'HeatIndexC': '37',
#      'HeatIndexF': '99',
#      'WindChillC': '33',
#      'WindChillF': '91',
#      'WindGustKmph': '12',
#      'WindGustMiles': '7',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '94',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '89',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '88',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '13',
#      'diffRad': '78.2',
#      'humidity': '53',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1007',
#      'pressureInches': '30',
#      'shortRad': '215.7',
#      'tempC': '33',
#      'tempF': '91',
#      'time': '900',
#      'uvIndex': '5',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'SW',
#      'winddirDegree': '227',
#      'windspeedKmph': '10',
#      'windspeedMiles': '6'},
#     {'DewPointC': '19',
#      'DewPointF': '65',
#      'FeelsLikeC': '42',
#      'FeelsLikeF': '107',
#      'HeatIndexC': '42',
#      'HeatIndexF': '107',
#      'WindChillC': '39',
#      'WindChillF': '101',
#      'WindGustKmph': '5',
#      'WindGustMiles': '3',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '93',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '83',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '85',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '9',
#      'diffRad': '122.7',
#      'humidity': '31',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1004',
#      'pressureInches': '30',
#      'shortRad': '981.7',
#      'tempC': '39',
#      'tempF': '101',
#      'time': '1200',
#      'uvIndex': '10',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'WSW',
#      'winddirDegree': '257',
#      'windspeedKmph': '4',
#      'windspeedMiles': '3'},
#     {'DewPointC': '16',
#      'DewPointF': '61',
#      'FeelsLikeC': '43',
#      'FeelsLikeF': '110',
#      'HeatIndexC': '43',
#      'HeatIndexF': '110',
#      'WindChillC': '41',
#      'WindChillF': '106',
#      'WindGustKmph': '7',
#      'WindGustMiles': '4',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '93',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '94',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '86',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '6',
#      'diffRad': '86.6',
#      'humidity': '23',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1000',
#      'pressureInches': '30',
#      'shortRad': '892.2',
#      'tempC': '41',
#      'tempF': '106',
#      'time': '1500',
#      'uvIndex': '4',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'WNW',
#      'winddirDegree': '301',
#      'windspeedKmph': '6',
#      'windspeedMiles': '4'},
#     {'DewPointC': '16',
#      'DewPointF': '61',
#      'FeelsLikeC': '41',
#      'FeelsLikeF': '105',
#      'HeatIndexC': '41',
#      'HeatIndexF': '105',
#      'WindChillC': '39',
#      'WindChillF': '103',
#      'WindGustKmph': '3',
#      'WindGustMiles': '2',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '92',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '93',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '86',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '5',
#      'diffRad': '22.4',
#      'humidity': '26',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1000',
#      'pressureInches': '30',
#      'shortRad': '46.4',
#      'tempC': '39',
#      'tempF': '103',
#      'time': '1800',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'E',
#      'winddirDegree': '91',
#      'windspeedKmph': '2',
#      'windspeedMiles': '1'},
#     {'DewPointC': '22',
#      'DewPointF': '72',
#      'FeelsLikeC': '37',
#      'FeelsLikeF': '98',
#      'HeatIndexC': '37',
#      'HeatIndexF': '98',
#      'WindChillC': '32',
#      'WindChillF': '90',
#      'WindGustKmph': '31',
#      'WindGustMiles': '19',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '92',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '82',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '89',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '3',
#      'diffRad': '5.6',
#      'humidity': '54',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1004',
#      'pressureInches': '30',
#      'shortRad': '11.6',
#      'tempC': '32',
#      'tempF': '90',
#      'time': '2100',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Clear '}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#      'winddir16Point': 'SE',
#      'winddirDegree': '132',
#      'windspeedKmph': '24',
#      'windspeedMiles': '15'}],
#    'maxtempC': '41',
#    'maxtempF': '106',
#    'mintempC': '28',
#    'mintempF': '82',
#    'sunHour': '13.0',
#    'totalSnow_cm': '0.0',
#    'uvIndex': '10'},
#   {'astronomy': [{'moon_illumination': '2',
#      'moon_phase': 'Waxing Crescent',
#      'moonrise': '06:40 AM',
#      'moonset': '08:30 PM',
#      'sunrise': '05:37 AM',
#      'sunset': '06:35 PM'}],
#    'avgtempC': '37',
#    'avgtempF': '98',
#    'date': '2026-05-18',
#    'hourly': [{'DewPointC': '21',
#      'DewPointF': '69',
#      'FeelsLikeC': '35',
#      'FeelsLikeF': '94',
#      'HeatIndexC': '35',
#      'HeatIndexF': '94',
#      'WindChillC': '31',
#      'WindChillF': '89',
#      'WindGustKmph': '23',
#      'WindGustMiles': '14',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '91',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '85',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '89',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '3',
#      'diffRad': '0.0',
#      'humidity': '53',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1003',
#      'pressureInches': '30',
#      'shortRad': '0.0',
#      'tempC': '31',
#      'tempF': '89',
#      'time': '0',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Clear '}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#      'winddir16Point': 'SSE',
#      'winddirDegree': '161',
#      'windspeedKmph': '17',
#      'windspeedMiles': '11'},
#     {'DewPointC': '22',
#      'DewPointF': '72',
#      'FeelsLikeC': '33',
#      'FeelsLikeF': '92',
#      'HeatIndexC': '33',
#      'HeatIndexF': '92',
#      'WindChillC': '30',
#      'WindChillF': '85',
#      'WindGustKmph': '22',
#      'WindGustMiles': '14',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '90',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '83',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '89',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '0',
#      'diffRad': '0.0',
#      'humidity': '65',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1002',
#      'pressureInches': '30',
#      'shortRad': '0.0',
#      'tempC': '30',
#      'tempF': '85',
#      'time': '300',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Clear '}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#      'winddir16Point': 'S',
#      'winddirDegree': '180',
#      'windspeedKmph': '16',
#      'windspeedMiles': '10'},
#     {'DewPointC': '23',
#      'DewPointF': '73',
#      'FeelsLikeC': '34',
#      'FeelsLikeF': '94',
#      'HeatIndexC': '34',
#      'HeatIndexF': '94',
#      'WindChillC': '30',
#      'WindChillF': '86',
#      'WindGustKmph': '16',
#      'WindGustMiles': '10',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '90',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '94',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '91',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '8',
#      'diffRad': '18.0',
#      'humidity': '64',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1005',
#      'pressureInches': '30',
#      'shortRad': '39.1',
#      'tempC': '30',
#      'tempF': '86',
#      'time': '600',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'SE',
#      'winddirDegree': '142',
#      'windspeedKmph': '13',
#      'windspeedMiles': '8'},
#     {'DewPointC': '20',
#      'DewPointF': '68',
#      'FeelsLikeC': '41',
#      'FeelsLikeF': '106',
#      'HeatIndexC': '41',
#      'HeatIndexF': '106',
#      'WindChillC': '37',
#      'WindChillF': '99',
#      'WindGustKmph': '12',
#      'WindGustMiles': '8',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '89',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '92',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '87',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '6',
#      'diffRad': '53.8',
#      'humidity': '37',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1005',
#      'pressureInches': '30',
#      'shortRad': '362.7',
#      'tempC': '37',
#      'tempF': '99',
#      'time': '900',
#      'uvIndex': '5',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'SW',
#      'winddirDegree': '218',
#      'windspeedKmph': '11',
#      'windspeedMiles': '7'},
#     {'DewPointC': '18',
#      'DewPointF': '64',
#      'FeelsLikeC': '45',
#      'FeelsLikeF': '114',
#      'HeatIndexC': '45',
#      'HeatIndexF': '114',
#      'WindChillC': '42',
#      'WindChillF': '108',
#      'WindGustKmph': '15',
#      'WindGustMiles': '10',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '89',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '81',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '85',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '5',
#      'diffRad': '274.1',
#      'humidity': '24',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1002',
#      'pressureInches': '30',
#      'shortRad': '951.2',
#      'tempC': '42',
#      'tempF': '108',
#      'time': '1200',
#      'uvIndex': '10',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'WSW',
#      'winddirDegree': '252',
#      'windspeedKmph': '13',
#      'windspeedMiles': '8'},
#     {'DewPointC': '13',
#      'DewPointF': '56',
#      'FeelsLikeC': '47',
#      'FeelsLikeF': '117',
#      'HeatIndexC': '47',
#      'HeatIndexF': '117',
#      'WindChillC': '44',
#      'WindChillF': '112',
#      'WindGustKmph': '10',
#      'WindGustMiles': '6',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '88',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '82',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '87',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '7',
#      'diffRad': '306.2',
#      'humidity': '16',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '998',
#      'pressureInches': '29',
#      'shortRad': '809.4',
#      'tempC': '44',
#      'tempF': '112',
#      'time': '1500',
#      'uvIndex': '2',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'N',
#      'winddirDegree': '355',
#      'windspeedKmph': '8',
#      'windspeedMiles': '5'},
#     {'DewPointC': '12',
#      'DewPointF': '54',
#      'FeelsLikeC': '42',
#      'FeelsLikeF': '107',
#      'HeatIndexC': '42',
#      'HeatIndexF': '107',
#      'WindChillC': '41',
#      'WindChillF': '106',
#      'WindGustKmph': '9',
#      'WindGustMiles': '5',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '88',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '87',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '87',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '20',
#      'diffRad': '27.5',
#      'humidity': '18',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '999',
#      'pressureInches': '30',
#      'shortRad': '56.6',
#      'tempC': '41',
#      'tempF': '106',
#      'time': '1800',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Sunny'}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#      'winddir16Point': 'SW',
#      'winddirDegree': '221',
#      'windspeedKmph': '5',
#      'windspeedMiles': '3'},
#     {'DewPointC': '18',
#      'DewPointF': '64',
#      'FeelsLikeC': '38',
#      'FeelsLikeF': '100',
#      'HeatIndexC': '38',
#      'HeatIndexF': '100',
#      'WindChillC': '36',
#      'WindChillF': '97',
#      'WindGustKmph': '23',
#      'WindGustMiles': '14',
#      'chanceoffog': '0',
#      'chanceoffrost': '0',
#      'chanceofhightemp': '87',
#      'chanceofovercast': '0',
#      'chanceofrain': '0',
#      'chanceofremdry': '81',
#      'chanceofsnow': '0',
#      'chanceofsunshine': '90',
#      'chanceofthunder': '0',
#      'chanceofwindy': '0',
#      'cloudcover': '2',
#      'diffRad': '6.9',
#      'humidity': '34',
#      'precipInches': '0.0',
#      'precipMM': '0.0',
#      'pressure': '1002',
#      'pressureInches': '30',
#      'shortRad': '14.1',
#      'tempC': '36',
#      'tempF': '97',
#      'time': '2100',
#      'uvIndex': '0',
#      'visibility': '10',
#      'visibilityMiles': '6',
#      'weatherCode': '113',
#      'weatherDesc': [{'value': 'Clear '}],
#      'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#      'winddir16Point': 'S',
#      'winddirDegree': '179',
#      'windspeedKmph': '17',
#      'windspeedMiles': '11'}],
#    'maxtempC': '44',
#    'maxtempF': '112',
#    'mintempC': '29',
#    'mintempF': '85',
#    'sunHour': '13.0',
#    'totalSnow_cm': '0.0',
#    'uvIndex': '10'}]}

# %%
temperature = weather_data[
    'current_condition'
][0]['temp_C']

humidity = weather_data[
    'current_condition'
][0]['humidity']

print("Temperature:", temperature)

print("Humidity:", humidity)
# Out:
# Temperature: 32
# Humidity: 54
